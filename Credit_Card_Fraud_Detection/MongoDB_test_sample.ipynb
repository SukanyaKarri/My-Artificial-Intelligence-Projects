# %%
# !pip install numpy

import pandas as pd
# !pip install xlrd

# %%
df = pd.read_excel(r'C:\Users\KSUKA\OneDrive\Desktop\Chinnana\article list Format _Updated (1).xls', engine='xlrd')
print(df.head())
# Out:
#   Relocation Request Form                                         Unnamed: 1  \
# 0           Customer Name  Grasim Industries Limited ,Unit: Harihar Polyf...
# 1            Telephone No                                         6281799545
# 2                Email ID                         doddaraviram3339@gmail.com
# 3     Billing Entity Name                                                NaN
# 4          Origin Address  Staff colony,1/8 Cluster,ITC-PSPD, Sarapaka,Bh...
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 8 Unnamed: 9
# 0        NaN        NaN
# 1        NaN        NaN
# ...
