# %%
# !pip install pymongo
import pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/955.0 kB ? eta -:--:--
#    ---------------------------------------- 955.0/955.0 kB 7.3 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pymongo

# %%
import pymongo
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]

# %%
print(mydb.list_collection_names())
# Out:
# []

# %%
import pymongo

# Connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")

# Create or connect to a database and collection
db = client["mydatabase"]
collection = db["testcollection"]

# Insert a document to ensure collection exists
collection.insert_one({"name": "Srinu", "age": 33, "gender": "OF", "state": "AP"})

# Now list the collections in this database
print("✅ Collections in 'mydatabase':", db.list_collection_names())
# Out:
# ✅ Collections in 'mydatabase': ['testcollection']

# %%
for doc in collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('684da4c5bf77a6b376fd3dd4'), 'name': 'Srinu', 'age': 33, 'gender': 'OF', 'state': 'AP'}

# %%
collection.update_one(
    {"name": "Srinu"},
    {"$set": {"food": "choco"}}
)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
collection.delete_one({"name": "Srinu"})
# Out:
# DeleteResult({'n': 1, 'ok': 1.0}, acknowledged=True)

# %%
for doc in collection.find({}, {"_id": 0, "name": 1, "gender": 1}):
    print(doc)

# %%
for doc in customer.find({"name":"Mom"}):
    print(doc)

# %%
dblist=myclient.list_database_names()

# %%
print(mydb.list_collection_names())
print("Databases:", dblist)
# Out:
# ['testcollection']
# Databases: ['admin', 'config', 'local', 'mydatabase', 'sri_test', 'temp']

# %%
if "mydatabase" in dblist:
    print("Datbase Exists!")
# Out:
# Datbase Exists!

# %%
my_col=mydb["sri_test"]
print(my_col)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'mydatabase'), 'sri_test')

# %%
# Insert a document to ensure collection exists
my_list=[
    {"name":"sample1", "age": 33},
    {"name":"sample2", "age": 34},
    {"name":"sample3", "age": 35},
    {"name":"sample4", "age": 36},
    {"name":"sample5", "age": 37}]

x=collection.insert_many(my_list)

# %%
print("Inserted IDs:", x.inserted_ids)

# Or see all documents:
for doc in collection.find():
    print(doc)
# Out:
# Inserted IDs: [ObjectId('684da8aebf77a6b376fd3dd5'), ObjectId('684da8aebf77a6b376fd3dd6'), ObjectId('684da8aebf77a6b376fd3dd7'), ObjectId('684da8aebf77a6b376fd3dd8'), ObjectId('684da8aebf77a6b376fd3dd9')]
# {'_id': ObjectId('684da8aebf77a6b376fd3dd5'), 'name': 'sample1', 'age': 33}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd6'), 'name': 'sample2', 'age': 34}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd7'), 'name': 'sample3', 'age': 35}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd8'), 'name': 'sample4', 'age': 36}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd9'), 'name': 'sample5', 'age': 37}

# %%
for doc in collection.find():
    print(doc)
# Out:
# {'_id': ObjectId('684da8aebf77a6b376fd3dd5'), 'name': 'sample1', 'age': 33}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd6'), 'name': 'sample2', 'age': 34}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd7'), 'name': 'sample3', 'age': 35}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd8'), 'name': 'sample4', 'age': 36}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd9'), 'name': 'sample5', 'age': 37}

# %%
x=collection.find()
for i in x:
    print(i)
# Out:
# {'_id': ObjectId('684da8aebf77a6b376fd3dd5'), 'name': 'sample1', 'age': 33}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd6'), 'name': 'sample2', 'age': 34}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd7'), 'name': 'sample3', 'age': 35}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd8'), 'name': 'sample4', 'age': 36}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd9'), 'name': 'sample5', 'age': 37}

# %%
x=collection.find().limit(2)
for i in x:
    print(i)
# Out:
# {'_id': ObjectId('684da8aebf77a6b376fd3dd5'), 'name': 'sample1', 'age': 33}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd6'), 'name': 'sample2', 'age': 34}

# %%
#display only name key
x=collection.find({},{"name":1,"_id":False}).limit(3)
for i in x:
    print(i)
# Out:
# {'name': 'sample1'}
# {'name': 'sample2'}
# {'name': 'sample3'}

# %%
#find doc where letter starts witn M or higher
my_query={"name":{"$gt":"M"}}
x=collection.find(my_query)
for i in x:
    print(i)
# Out:
# {'_id': ObjectId('684da8aebf77a6b376fd3dd5'), 'name': 'sample1', 'age': 33}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd6'), 'name': 'sample2', 'age': 34}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd7'), 'name': 'sample3', 'age': 35}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd8'), 'name': 'sample4', 'age': 36}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd9'), 'name': 'sample5', 'age': 37}

# %%
#find doc where letter starts witn M or higher
my_query={"name":{"$regex":"^s"}}

x=collection.find(my_query).limit(3)
for i in x:
    print(i)
# Out:
# {'_id': ObjectId('684da8aebf77a6b376fd3dd5'), 'name': 'sample1', 'age': 33}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd6'), 'name': 'sample2', 'age': 34}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd7'), 'name': 'sample3', 'age': 35}

# %%
#get all names and sort by age
x=collection.find({}).sort("age", pymongo.DESCENDING)
for i in x:
    print(i)
# Out:
# {'_id': ObjectId('684da8aebf77a6b376fd3dd9'), 'name': 'sample5', 'age': 37}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd8'), 'name': 'sample4', 'age': 36}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd7'), 'name': 'sample3', 'age': 35}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd6'), 'name': 'sample2', 'age': 34}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd5'), 'name': 'sample1', 'age': 33}

# %%
#get all names and sort by age
x=collection.find({}).sort("age",1) # 1- ascending, 0-descending
for i in x:
    print(i)
# Out:
# {'_id': ObjectId('684da8aebf77a6b376fd3dd5'), 'name': 'sample1', 'age': 33}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd6'), 'name': 'sample2', 'age': 34}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd7'), 'name': 'sample3', 'age': 35}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd8'), 'name': 'sample4', 'age': 36}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd9'), 'name': 'sample5', 'age': 37}

# %%
#delete
query=({"age":33})
x=collection.delete_one(query)
print(x)
# Out:
# DeleteResult({'n': 0, 'ok': 1.0}, acknowledged=True)

# %%
x=collection.find()
for i in x:
    print(i)
# Out:
# {'_id': ObjectId('684da8aebf77a6b376fd3dd6'), 'name': 'sample2', 'age': 34}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd7'), 'name': 'sample3', 'age': 35}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd8'), 'name': 'sample4', 'age': 36}
# {'_id': ObjectId('684da8aebf77a6b376fd3dd9'), 'name': 'sample5', 'age': 37}

# %%
class Mongo_query:
    def__init__(self,connection_string):
        self.myclient=pymongo.MongoClient(connection_string)
    def create_database(self,database_name):
        self.my_database=myclient[database_name]
    def create_column(self,collection_name):
        self.my_collection=self.my_database[collection_name]
    def create(self,query,how="one"):
        """this fucntion insets the value in the database parameters
        query{dict} : query to insert
        how{str} : one or many, default is one
        """

        if how=="one":
            self.my_collection.insert_one(query)
            print("Element inserted successfully.")
        if how=="many":
            self.my_collection.insert_many(query)
            print("Element inserted successfully.")
        else:
            raise ValueError("Invalid value for 'how'. Use 'one' or 'many'.")
        
        if how=="one":
            return self.my_collection.find_one(query)
        if how=="many":
            return self.my_collection.find(query)
        
        def update(self):
            pass
        def delete(self):
            pass
        mongo=Mongo_query("mongodb://localhost:27017/")
        mongo.create_database("test_db")
        mongo.create_column("test_collection")
        mongo.create({"name": "John", "age": 30}, how="one")
        mongo.create([{"name": "Alice", "age": 25}, {"name": "Bob", "age": 28}], how="many")
